# %% [markdown]
# ##CSE-221710304026-K. Vijayalakshmi

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_csv('https://raw.githubusercontent.com/lohith4034/AIML/master/18-6-2020/Placement_Data_Full_Class.csv')
df
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# 214    215      M  62.00  Central  ...          Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
# Get the number of rows and columns from the dataset
print(df.shape[0])# no. of rows
print(df.shape[1])# no. of columns
# Out:
# 215
# 15

# %%
#Check how many categorical and numerical columns are there
print(len(df.select_dtypes(include=['object']).columns)) # no of Categorial columns
print(len(df.select_dtypes(include=['int64','float64']).columns)) # no of Numerical columns
# Out:
# 8
# 7

# %%
#Get the basic descriptive information from the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.describe()
# Out:
#             sl_no       ssc_p  ...       mba_p         salary
# count  215.000000  215.000000  ...  215.000000     148.000000
# mean   108.000000   67.303395  ...   62.278186  288655.405405
# std     62.209324   10.827205  ...    5.833385   93457.452420
# min      1.000000   40.890000  ...   51.210000  200000.000000
# 25%     54.500000   60.600000  ...   57.945000  240000.000000
# 50%    108.000000   67.000000  ...   62.000000  265000.000000
# 75%    161.500000   75.700000  ...   66.255000  300000.000000
# max    215.000000   89.400000  ...   77.890000  940000.000000
#
# [8 rows x 7 columns]

# %%
# Get the frequency of the categories in all the columns of the dataset
print(df.gender.value_counts())
print(df['ssc_b'].value_counts())
print(df['hsc_b'].value_counts())
print(df['hsc_s'].value_counts())
print(df['degree_t'].value_counts())
print(df['specialisation'].value_counts())
print(df['status'].value_counts())
# Out:
# M    139
# F     76
# Name: gender, dtype: int64
# Central    116
# Others      99
# Name: ssc_b, dtype: int64
# Others     131
# Central     84
# Name: hsc_b, dtype: int64
# Commerce    113
# Science      91
# Arts         11
# Name: hsc_s, dtype: int64
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
#Check for the missing values and if found any visualize the missing values using seaborn, missingno libraries.
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
sns.heatmap(df.isna())

# %%
import missingno as msno
msno.matrix(df)

# %%
msno.bar(df)

# %%
# Impute the missing values based on numerical and categorical
df_mean_imputed = df.fillna(df.mean())
df_median_imputed = df.fillna(df.median())
df_zero_imputed = df.fillna(0)

# %%
df_mean_imputed
# Out:
#      sl_no gender  ssc_p  ...  mba_p      status         salary
# 0        1      M  67.00  ...  58.80      Placed  270000.000000
# 1        2      M  79.33  ...  66.28      Placed  200000.000000
# 2        3      M  65.00  ...  57.80      Placed  250000.000000
# 3        4      M  56.00  ...  59.43  Not Placed  288655.405405
# 4        5      M  85.80  ...  55.50      Placed  425000.000000
# ..     ...    ...    ...  ...    ...         ...            ...
# 210    211      M  80.60  ...  74.49      Placed  400000.000000
# 211    212      M  58.00  ...  53.62      Placed  275000.000000
# 212    213      M  67.00  ...  69.72      Placed  295000.000000
# 213    214      F  74.00  ...  60.23      Placed  204000.000000
# 214    215      M  62.00  ...  60.22  Not Placed  288655.405405
#
# [215 rows x 15 columns]

# %%
df_median_imputed
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed  265000.0
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# 214    215      M  62.00  Central  ...          Mkt&HR  60.22  Not Placed  265000.0
#
# [215 rows x 15 columns]

# %%
df_zero_imputed
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       0.0
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# 214    215      M  62.00  Central  ...          Mkt&HR  60.22  Not Placed       0.0
#
# [215 rows x 15 columns]

# %%
# Plot all the columns from the dataset; try to get some observations from the plot and write your inferences below the plots generated
df.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff1438d3278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff14382b438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff1437db668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff14380b8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff1437c1b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff143775da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff143728fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff1436e7278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff1436e72e8>]],
#       dtype=object)

# %%
df.gender.value_counts(normalize=True)
# Out:
# M    0.646512
# F    0.353488
# Name: gender, dtype: float64

# %%
sns.countplot(df['gender'])

# %%
(df.gender.value_counts(normalize=True)*100).plot.barh()

# %%
(df.gender.value_counts(normalize=True)*100).plot.barh().set_title("No of Males and Females")
# Out:
# Text(0.5, 1.0, 'No of Males and Females')

# %%
# Encode the categorical columns using different kinds of encoding techniques from pandas and scikit-learn
merge_d=pd.get_dummies(df,columns=['gender','ssc_b','hsc_b','hsc_s','degree_t','workex','specialisation','status'])
merge_d
# Out:
#      sl_no  ssc_p  ...  status_Not Placed  status_Placed
# 0        1  67.00  ...                  0              1
# 1        2  79.33  ...                  0              1
# 2        3  65.00  ...                  0              1
# 3        4  56.00  ...                  1              0
# 4        5  85.80  ...                  0              1
# ..     ...    ...  ...                ...            ...
# 210    211  80.60  ...                  0              1
# 211    212  58.00  ...                  0              1
# 212    213  67.00  ...                  0              1
# 213    214  74.00  ...                  0              1
# 214    215  62.00  ...                  1              0
#
# [215 rows x 25 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() # creating an object
merge_d=sc.fit_transform(merge_d)
merge_d
# Out:
# array([[-1.72401341, -0.02808697,  2.2688123 , ...,  1.12390297,
#         -0.67283185,  0.67283185],
#        [-1.70790113,  1.11336869,  1.10344799, ..., -0.88975652,
#         -0.67283185,  0.67283185],
#        [-1.69178886, -0.21323793,  0.15331275, ..., -0.88975652,
#         -0.67283185,  0.67283185],
#        ...,
#        [ 1.69178886, -0.02808697,  0.06133451, ..., -0.88975652,
#         -0.67283185,  0.67283185],
#        [ 1.70790113,  0.61994138, -0.03064373, ...,  1.12390297,
#         -0.67283185,  0.67283185],
#        [ 1.72401341, -0.49096436, -0.76646966, ...,  1.12390297,
#          1.48625544, -1.48625544]])

# %%
merge_d=pd.DataFrame(merge_d)
merge_d
# Out:
#            0         1         2   ...        22        23        24
# 0   -1.724013 -0.028087  2.268812  ...  1.123903 -0.672832  0.672832
# 1   -1.707901  1.113369  1.103448  ... -0.889757 -0.672832  0.672832
# 2   -1.691789 -0.213238  0.153313  ... -0.889757 -0.672832  0.672832
# 3   -1.675677 -1.046417 -1.318339  ...  1.123903  1.486255 -1.486255
# 4   -1.659564  1.712332  0.668391  ... -0.889757 -0.672832  0.672832
# ..        ...       ...       ...  ...       ...       ...       ...
# 210  1.659564  1.230940  1.441008  ... -0.889757 -0.672832  0.672832
# 211  1.675677 -0.861266 -0.582513  ... -0.889757 -0.672832  0.672832
# 212  1.691789 -0.028087  0.061335  ... -0.889757 -0.672832  0.672832
# 213  1.707901  0.619941 -0.030644  ...  1.123903 -0.672832  0.672832
# 214  1.724013 -0.490964 -0.766470  ...  1.123903  1.486255 -1.486255
#
# [215 rows x 25 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

ct=ColumnTransformer(transformers=[('Encoder',OneHotEncoder(),['status'])],remainder="passthrough")

df1=ct.fit_transform(df)
df1=pd.DataFrame(df1)
df1=df1.iloc[:,0:2]
df1.columns=['status_Placed','status_Not Placed']
df1=pd.concat([df,df1],axis=1)
df1=df1.drop('status',axis=1)
df1
# Out:
#      sl_no gender  ssc_p  ...    salary  status_Placed status_Not Placed
# 0        1      M  67.00  ...  270000.0              0                 1
# 1        2      M  79.33  ...  200000.0              0                 1
# 2        3      M  65.00  ...  250000.0              0                 1
# 3        4      M  56.00  ...       NaN              1                 0
# 4        5      M  85.80  ...  425000.0              0                 1
# ..     ...    ...    ...  ...       ...            ...               ...
# 210    211      M  80.60  ...  400000.0              0                 1
# 211    212      M  58.00  ...  275000.0              0                 1
# 212    213      M  67.00  ...  295000.0              0                 1
# 213    214      F  74.00  ...  204000.0              0                 1
# 214    215      M  62.00  ...       NaN              1                 0
#
# [215 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1.Sex=le.fit_transform(df1.gender)
df1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until
#      sl_no gender  ssc_p  ...    salary  status_Placed status_Not Placed
# 0        1      M  67.00  ...  270000.0              0                 1
# 1        2      M  79.33  ...  200000.0              0                 1
# 2        3      M  65.00  ...  250000.0              0                 1
# 3        4      M  56.00  ...       NaN              1                 0
# 4        5      M  85.80  ...  425000.0              0                 1
# ..     ...    ...    ...  ...       ...            ...               ...
# 210    211      M  80.60  ...  400000.0              0                 1
# 211    212      M  58.00  ...  275000.0              0                 1
# 212    213      M  67.00  ...  295000.0              0                 1
# 213    214      F  74.00  ...  204000.0              0                 1
# 214    215      M  62.00  ...       NaN              1                 0
#
# [215 rows x 16 columns]
