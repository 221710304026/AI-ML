# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image=plt.imread("/content/drive/My Drive/Summer Internship/color.jpg")
print(image.shape)
# Out:
# (168, 300, 3)

# %%
plt.imshow(image)

# %%
plt.imshow(image[:,:,0])

# %%
plt.imshow(image[:,:,0],cmap='gray')

# %%
plt.imshow(image[:,:125,:])
